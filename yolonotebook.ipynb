# %%
import os
from ultralytics import YOLO

# %%
data_dir = r"C:\Users\sayan\.cache\kagglehub\datasets\yolo_dataset\myopia-image-dataset\versions\1"

# %%
model = YOLO("yolov8n-cls.pt")

results = model.train(data=data_dir, epochs=1, imgsz=64)
# Out:
# Ultralytics 8.3.161  Python-3.12.4 torch-2.7.1+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# ...
